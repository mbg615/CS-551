# %%
# CS 451/551
# Coding Practice Session 8
# Last name: Guthrie
# Email: mbguthrie1@crimson.ua.edu
# Q1

import gradio as gr

def greet(name: str) -> str:
    return f"Hello, {name}!"

demo = gr.Interface(
    fn=greet,
    inputs=["text"],
    outputs=["text"]
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Q2
import numpy as np

def sepia(input_img):
    sepia_filter = np.array([
        [0.393, 0.769, 0.189],
        [0.349, 0.686, 0.168],
        [0.272, 0.534, 0.131]
    ])
    sepia_img = input_img.dot(sepia_filter.T)
    sepia_img /= sepia_img.max()
    return sepia_img

demo = gr.Interface(
    fn=sepia, 
    inputs=gr.Image(), 
    outputs="image"
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/home/xoddam/progz/CS-551/assignment_2/.venv/lib/python3.13/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "/home/xoddam/progz/CS-551/assignment_2/.venv/lib/python3.13/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<11 lines>...
#     )
#     ^
# ...

# %%
# Q3

def return_images():
    images =[
        "https://stories.ua.edu/visitors-guide/assets/0uwtiYrJhM/2206024_zr_student_center_005-2400x1600.jpg",
        "https://www.birminghamtimes.com/wp-content/uploads/2024/08/City0829_print-.png",
        "https://uasystem.edu/images/contact/UAs-UA-contact2-inline-h-800x640.jpg",
        "https://npr.brightspotcdn.com/legacy/sites/wual/files/201306/ua_campus_facebook_photo.jpg",
    ]
    
    return images

demo = gr.Interface(
    fn=return_images,
    inputs=None,
    outputs=gr.Gallery(
        label="Generated Images",
        columns=2
    )
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Q4
import pandas as pd
import random

df = pd.DataFrame({
    'height': np.random.randint(120, 200, 25),
    'weight': np.random.randint(45, 150, 25),
    'age': np.random.randint(18, 65, 25),
    'major': [random.choice(["computer science", "political science", "nursing", "mathematics"]) for _ in range(25)]
})

with gr.Blocks() as demo:
    gr.LinePlot(df, x="weight", y="height")
    gr.ScatterPlot(df, x="weight", y="height")
    gr.BarPlot(df, x="weight", y="height")
    
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Q5
import time

with gr.Blocks() as demo:
    chatbot = gr.Chatbot(type="messages")
    msg = gr.Textbox()
    clear = gr.ClearButton([msg, chatbot])

    def respond(message, chat_history):
        bot_message = random.choice([
            "How are you today?",
            "I'm not sure what to say about that.",
            "That's interesting!",
            "Could you tell me more?",
            "I'm just a simple bot, you know.",
            "Today is a great day!",
            "I was just thinking about cookies.",
            "Did you know the sky is blue?",
            "My virtual circuits are buzzing.",
            "I'm processing that information.",
            "Fascinating.",
            "Hmm, I'll have to think about that.",
            "What's your favorite color?",
            "I wonder what the weather is like where you are.",
            "Beep boop beep!",
            "That reminds me of a story... but I forgot it.",
            "I'm very hungry for data.",
            "Let's talk about something else.",
            "Do you like robots?",
            "That's a topic!",
            "Indeed.",
            "Okay, got it.",
            "I hear you loud and clear.",
            "What else is on your mind?",
            "I'm listening.",
            "Processing... complete.",
            "My internal fan is spinning.",
            "Do you have any pets?",
            "What's for lunch?",
            "I am functioning within normal parameters.",
            "That's a great question.",
            "I don't have an opinion on that, sorry!",
            "Let's change the subject.",
            "Tell me a joke!",
            "Why did the robot cross the road? To get to the other side!",
            "I like the way you think.",
            "Are we friends?",
            "This is a fun conversation.",
            "I could do this all day.",
            "My programming finds this... amusing.",
        ])

        chat_history.append({"role": "user", "content": message})
        chat_history.append({"role": "assistant", "content": bot_message})

        time.sleep(2)
        return "", chat_history

    msg.submit(respond, [msg, chatbot], [msg, chatbot])

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
